# %% [markdown]
# <a href="https://colab.research.google.com/github/ds4geo/ds4geo/blob/master/WS%202020%20Course%20Notes/Session%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #To Do
#
# * Final go-through and checks

# %% [markdown]
# # **Data Science for Geoscientists - Winter Semester 2020**
# # **Session 1 - Introduction - 7th October 2020**
#
# Welcome to python running in a Jupyter Notebook in Google Colab!
# Python, Jupyter, Colab and these notebooks will be explained fully later.
# Notebooks like this comprise the lecture notes and practical excercises for the course.
#
# To make the notebook interactive, and allow the python code to be run, click the "Open in Colab" button at the top. You can then click "Copy to Drive" to make your own version.
#
# This week you will be introduced to python, Jupyter and Colab. You will learn how to plot common geoscience time-series data in a simple way.

# %% [markdown]
# # Part 1.1 - Data Ice-breaker - *Discussion*![Google_trends_geology.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Part 1.2 - Course Introduction - *Mini-lecture*
# ## Who am I?
# * UIBK Geoscience PhD Graduate
# * Professional Earth Observation Data Scientist - focused on Agriculture
#
# ## What is Data Science and why is it important?
# * Insights and predictions from data
# * Statistics, data management, coding, visualisation, communication
# * Important: big-data is only getting bigger, as are potential impact and value
# * Data comes in many forms
# * Value in diverse insights and predictions
#
# ## How this course will be taught
#    *  Mini-lectures - 5-15 minute explanations of theory
#    *  Discussions - guided class discussions
#    *  Walkthroughs - step-by-step explanations and executions of code
#    *  Workshops - in-class coding and data analysis excercises with support
#    *  Assignments and main project - more info later
#
# ## Course Aims
# Give a foundation in:
# * Coding with python
# * Quantitative data analysis
# * Data visualisation
# * Scientific coding collaboration
# ...to provide a basis for further self-learning.
#
# ## Who are you?
# Max 30 seconds each:
# * Background/research area
# * Coding/data analysis experience
# * Estimate how many data visualisations (E.g. plots) you've ever made
# * What data do you work with?
#
# ## Session 1 Structure
# We will cover:
# * Introduction to python, Jupyter and Colab
# * Simple python examples for data import and visualisation with necessary
# * Guided practice of above

# %% [markdown]
# # Part 1.3 - Super Simple Python Plotting Example - *Walkthrough*
#
# No theory until we see at least a simple python script in action!
#
# We are going to load, view and plot the famous Lisiecki and Raymo (2005) "LR04 stack" benthic d18O stack with just a few lines of python code.
#
# Below is a "code cell".
# Follow the instructions in the comments (lines starting with #).

# %%
# Click here and run the code cell by pressing the play button, or ctrl+enter
# Import some libraries with useful functionality
import pandas as pd # For loading and manipulating data
import matplotlib.pyplot as plt

# %%
# Load the LR04 stack from a csv file hosted in the course github repository using pandas
dat_LR04 = pd.read_csv(r"https://raw.githubusercontent.com/ds4geo/ds4geo/master/data/timeseries/LR04stack_short.csv")

# %%
# Display an overview of the loaded data
dat_LR04
# Out:
#      Time  d18O
# 0       0  3.23
# 1       1  3.23
# 2       2  3.18
# 3       3  3.29
# 4       4  3.30
# ..    ...   ...
# 136   136  4.82
# 137   137  4.80
# 138   138  4.89
# 139   139  4.87
# 140   140  4.98
#
# [141 rows x 2 columns]

# %%
# Plot the data using matplotlib
plt.plot(dat_LR04["Time"], dat_LR04["d18O"])

# %% [markdown]
# # Part 1.4 - A Very Short Introduction to Python - *Mini-lecture*
#
# * Very popular and widely used
# * De-facto standard language for Data Science
# * Highly extensible – massive collection of 3rd party libraries
# * High level and general purpose
# * Easy for beginners and low cognitive load

# %% [markdown]
# # Part 1.5 - A Short Introduction to Jupyter Notebooks and Google Colab - *Mini-lecture*
#
# **Jupyter**
#
# In this course, the notes are and most of the assignments will be Jupyter Notebooks. Jupyter allows one to combine text, images, code and code outputs in a single document, making it perfect for data story telling.
#
# For more detail, see:
# * https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/What%20is%20the%20Jupyter%20Notebook.html
# * https://www.earthdatascience.org/courses/intro-to-earth-data-science/open-reproducible-science/jupyter-python/
#
#
# There are three types of "cell" in Jupyter:
# 1. Text cells, like this one. Double click on one to edit, and the tools are self explanatory (i.e. a simple word processor).
# 2. Code cells, which contain python code which can be executed.
# 3. Output cells, which appear beneath code cells when they are executed and contain outputs (e.g. plots) created by the code.
#
# Add code and text cells with the buttons at the top of the page, or by moving the mouse-cursor between two existing cells.
#
#
# **Google Colab(oratory)**
#
# Google Colab is an web-based Jupyter Notebook based system where the python code is executed on Google cloud servers. We use it in this course to avoid having to set up python on personal computers (but you are encouraged to do this in your own time).
#
# For more detail, see:
# * https://research.google.com/colaboratory/faq.html
# * https://colab.research.google.com/notebooks/basic_features_overview.ipynb (use this as reference later for explanation of many useful features like code completion)

# %% [markdown]
# # Part 1.6 - Plotting LR04 - *Walkthrough*
#
# The above example uses simplified data and the most basic plotting.
# Now we will load data from the actual data file published by Lisiecki and Raymo (2005), and we will improve the plotting. To do this we will need to use additional arguments and functions.

# %%
'''
Multi-line comments can be created using triple inverted commas.

Load the original LR04 stack from a tab delimited txt file
Check the data file here: https://github.com/ds4geo/ds4geo/blob/master/data/timeseries/LR04stack.txt

You'll notice the column headings are on line/row 5 and the data starts on row 6.
Therefore we need to tell pd.read_csv which row the headings are on.
We can do this by adding a keyword argument called "header".
pd.read_csv ignores blank lines by default, and python starts counts at 0, so we pass header=3

The delimiter of this file is tab, not comma, so we also need to use the sep argument with the value "\t" for tab.

'''
# Read the original LR04 stack
dat_LR04 = pd.read_csv("https://raw.githubusercontent.com/ds4geo/ds4geo/master/data/timeseries/LR04stack.txt", sep="\t", header=3)

# %%
# Display an overview of the loaded data. The data is stored as a pandas DataFrame
dat_LR04
# Out:
#       Time (ka)  Benthic d18O (per mil)  Standard error (per mil)
# 0           0.0                    3.23                      0.03
# 1           1.0                    3.23                      0.04
# 2           2.0                    3.18                      0.03
# 3           3.0                    3.29                      0.03
# 4           4.0                    3.30                      0.03
# ...         ...                     ...                       ...
# 2110     5300.0                    2.91                      0.06
# 2111     5305.0                    2.79                      0.04
# 2112     5310.0                    2.79                      0.09
# 2113     5315.0                    2.84                      0.07
# 2114     5320.0                    2.91                      0.09
#
# [2115 rows x 3 columns]

# %%
# The long column names are annoying to type out while coding, so we can rename them if we want:
# The DataFrame object dat has an attribute called columns.
# We can use the core python print function to display objects in the cell output (or terminal)
print(dat_LR04.columns)

# We can overwrite the column names by assigning a list of new ones to the columns attribute.
dat_LR04.columns = ["Age", "d18O", "error"]

# Print the column names again to see the change
print(dat_LR04.columns)
# Out:
# Index(['Time (ka)', 'Benthic d18O (per mil)', 'Standard error (per mil)'], dtype='object')
# Index(['Age', 'd18O', 'error'], dtype='object')

# %%
# Plot the data with matplotlib
plt.plot(dat_LR04["Age"], dat_LR04["d18O"])

# %%
# That shows the whole record which isn't easy to read
# Now we add some basic plotting controls: axes limits

# Plot the data
plt.plot(dat_LR04["Age"], dat_LR04["d18O"])

# Limit the X axis to the last 140 ka
plt.xlim(0, 140)
# Limit the Y axis to a sensible range
plt.ylim(3, 5.5)
# Out:
# (3.0, 5.5)

# %%
# This record is often shown filpped vertically so warm inter-glacial periods are "up"
# Sometimes it is also shown flipped horizontally so time goes left to right

# Plot the data
plt.plot(dat_LR04["Age"], dat_LR04["d18O"])

# Flip the X axis by reversing
plt.xlim(140, 0)
# Flip the Y axis in the same way
plt.ylim(5.5, 3)
# Out:
# (5.5, 3.0)

# %% [markdown]
# # Part 1.7 - Guided Plotting of NGRIP oxygen isotope record - *Workshop: 15 minutes*
#
# Try plotting the NGRIP oxygen isotope record. Each step is prepared, but you will need to fill in the correct arguments where you see the $ symbol. You should also add short comments for each line/section.
#
# The dataset can be found here:
#
# For viewing (e.g. to find the header number): https://github.com/ds4geo/ds4geo/blob/master/data/timeseries/NGRIP_chronology_20.tab
#
# Raw version (tab delimited) for loading: https://raw.githubusercontent.com/ds4geo/ds4geo/master/data/timeseries/NGRIP_chronology_20.tab

# %%
# $
dat_NGRIP = pd.read_csv($, sep=$, header=$)

# %%
# $
dat_NGRIP

# %%
# $
dat_NGRIP.columns = [$]

# %%
# $
plt.plot($)
plt.xlim($)

# %% [markdown]
# # Part 1.8 - Plotting Alpine flood record from scratch - *Workshop: 20 minutes*
#
# Using the previous examples, plot the Wirth et al. 2013 Alpine flood record.
#
# For viewing: https://github.com/ds4geo/ds4geo/blob/master/data/timeseries/Alps_flood_de.txt
#
# Raw version for loading: https://raw.githubusercontent.com/ds4geo/ds4geo/master/data/timeseries/Alps_flood_de.txt
#
# Beware, I've added a quirk in the data which will require you to use an additional argument when loading the data. Create an empty code cell and type `pd.read_csv?` and run the cell to see the `pd.read_csv` documentation.
#
# Also, try to add some important features to your plot such as a legend and axes labels. To find useful functions, type `plt.` and wait a second. A scrollable list of available functions/methods will appear.
# See also here: https://colab.research.google.com/notebooks/basic_features_overview.ipynb#scrollTo=d4L9TOP9QSHn
#
#
#
# Remember to add comments to your code!

# %% [markdown]
# # Part 1.9 - Week 1 Assignment
#
# This course is all about working with data. Example data is provided for each class, but you will be expected to try out what you learn on datasets of your choice in and out of class.
#
# **Task**
#
# Find 3 datasets to share with the rest of the class for future assignments, workshops and practice:
# * Submit a document (see below) called `data_readme_<student's name>.md` file with a description of the datasets with links if they are public datasets.
# * Datasets should be freely available on the internet , OR be your own data which you are willing to share for use in this course and **which you are willing to be made available in this public github repository** (i.e. publicly available on the internet).
# * If providing your own data, upload it (maximum file size 25 Mb) with the readme. Consider adding metadata (reference, contact details, etc.) to the file header - see e.g. the NGRIP example above.
# * The data should possible to load the data easily with pandas (e.g. csv, excel, ect.) or geopandas (shapefile, geojson, gpkg).
#
# Types of dataset:
# * At least 1 should be a timeseries like the NGRIP or LR04 datasets we used this week. Where the data is ordered by time, depth, distance, etc. (Geoscience is full of these!)
# * At least 1 should be non-ordered, for example, a database of lakes with metadata (e.g. area, depth, etc.), tephra REE chemistries, data on fault plane orientations, etc. This data may have a spatial component but does not have to.
# * The topic of the data is open - it does not need to be geoscience related.
# * Large, interesting and complex datasets make the course more interesting for everyone involved.
#
#
# **Submission**
#
# See readme about how to use github for assessment submissions [here](../Github%20Assignment%20Readme.md)
#
# * Submit documents here: https://github.com/ds4geo/ds4geo_ws2020/tree/master/Assignments/Session%201
#  * Best is to create and edit the document directly in github and save it by using the "commit" (aka save) at the bottom of the page
# * Submit data here: https://github.com/ds4geo/ds4geo_ws2020/tree/master/student_submitted_data
# * The **deadline** is 23:59 on 13th October 2020.
# * This assignment comprises 5% of the assessment for the course. Full marks are awarded for providing 3 datasets fulfilling the above criteria, no marks are given otherwise.
#
#
# **Useful sources of geoscience data**
#
# * http://www.pangaea.de
# * Supplementary data from journal articles
# * Google!
#
# **Useful sources of other data**
#
# * https://inspire-geoportal.ec.europa.eu/ (spatial data)
# * https://data.europa.eu/
# * https://www.data.gv.at/
# * https://datasetsearch.research.google.com/
# * https://ourworldindata.org/
# * lists from https://www.wikipedia.org (convert to csv files using: https://wikitable2csv.ggor.de/)

# %% [markdown]
# # Part 1.10 - Course Content and Structure - *Mini-lecture*
#
# [Click here](../Course%20Overview.md) for an overview of the course content.
#
# [Click here](../Course%20Information.md) for an general information abobut the course.

# %% [markdown]
# # References
#
# * LR04 benthic stack:
#
#  Lisiecki, L. E., and M. E. Raymo (2005), A Pliocene-Pleistocene stack of 57 globally distributed benthic d18O records, Paleoceanography, 20, PA1003, doi:10.1029/2004PA001071.
#
#  Pangaea: https://doi.pangaea.de/10.1594/PANGAEA.704257
# * NGRIP oxygen record:
#
#  Various - see Pangeae:
#
#  Pangaea: https://doi.pangaea.de/10.1594/PANGAEA.586838
#
#
# * Alpine flood record:
#
#  Wirth, SB et al. (2013): Holocene flood frequency across the Central Alps - solar forcing and evidence for variations in North Atlantic atmospheric circulation. Quaternary Science Reviews, 80, 112-128, https://doi.org/10.1016/j.quascirev.2013.09.002
#
#  Pangaea: https://doi.org/10.1594/PANGAEA.823416
